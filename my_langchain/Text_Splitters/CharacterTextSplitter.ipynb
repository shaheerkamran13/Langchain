# %% [markdown]
# # CharacterTextSplitter
#
# The simplest method. This split is based on a given character sequence, defaulting to "\n\n". Chunk length is measured by number of characters.
#
# 1. How text is split?: By single character seperator.
# 2. How the chunk size is measured?: By number of characters.

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader('speech.txt')

docs = loader.load()

docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="Speech is the use of the human voice as a medium for language. Spoken language combines vowel and consonant sounds to form units of meaning like words, which belong to a language's lexicon. There are many different intentional speech acts, such as informing, declaring, asking, persuading, directing; acts may vary in various aspects like enunciation, intonation, loudness, and tempo to convey meaning. \n\nIndividuals may also unintentionally communicate aspects of their social position through speech, such as sex, age, place of origin, physiological and mental condition, education, and experiences.\n\nWhile normally used to facilitate communication with others, people may also use speech without the intent to communicate. Speech may nevertheless express emotions or desires; people talk to themselves sometimes in acts that are a development of what some psychologists (e.g., Lev Votsky) have maintained is the use of silent speech in an interior monologue to vivify and organize cognition, sometimes in the momentary adoption of a dual persona as self addressing self as though addressing another person. Solo speech can be used to memorize or to test one's memorization of things, and in prayer or in meditation.\n\nResearchers study many different aspects of speech: speech production and speech perception of the sounds used in a language, speech repetition, speech errors, the ability to map heard spoken words onto the vocalizations needed to recreate them, which plays a key role in children's enlargement of their vocabulary, and what different areas of the human brain, such as Broca's area and Wernicke's area, underlie speech. Speech is the subject of study for linguistics, cognitive science, communication studies, psychology, computer science, speech pathology, otolaryngology, and acoustics. \n\nSpeech compares with written language,[1] which may differ in its vocabulary, syntax, and phonetics from the spoken language, a situation called diglossia.\n\nThe evolutionary origin of speech is subject to debate and speculation. While animals also communicate using vocalizations, and trained apes such as Washoe and Kanzi can use simple sign language, no animals' vocalizations are articulated phonemically and syntactically, and do not constitute speech.")]

# %%
from langchain_text_splitters import CharacterTextSplitter

text_splitter = CharacterTextSplitter(separator="\n\n", chunk_size = 100, chunk_overlap = 20)

text_splitter.split_documents(docs)
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Speech is the use of the human voice as a medium for language. Spoken language combines vowel and'),
#  Document(metadata={'source': 'speech.txt'}, page_content='combines vowel and consonant sounds to form units of meaning like words, which belong to a'),
#  Document(metadata={'source': 'speech.txt'}, page_content="which belong to a language's lexicon. There are many different intentional speech acts, such as"),
#  Document(metadata={'source': 'speech.txt'}, page_content='speech acts, such as informing, declaring, asking, persuading, directing; acts may vary in various'),
#  Document(metadata={'source': 'speech.txt'}, page_content='may vary in various aspects like enunciation, intonation, loudness, and tempo to convey meaning.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='to convey meaning. \n\nIndividuals may also unintentionally communicate aspects of their social'),
#  Document(metadata={'source': 'speech.txt'}, page_content='of their social position through speech, such as sex, age, place of origin, physiological and mental'),
#  Document(metadata={'source': 'speech.txt'}, page_content='and mental condition, education, and experiences.\n\nWhile normally used to facilitate communication'),
#  Document(metadata={'source': 'speech.txt'}, page_content='communication with others, people may also use speech without the intent to communicate. Speech may'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Speech may nevertheless express emotions or desires; people talk to themselves sometimes in acts'),
#  Document(metadata={'source': 'speech.txt'}, page_content='sometimes in acts that are a development of what some psychologists (e.g., Lev Votsky) have'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Lev Votsky) have maintained is the use of silent speech in an interior monologue to vivify and'),
#  Document(metadata={'source': 'speech.txt'}, page_content='to vivify and organize cognition, sometimes in the momentary adoption of a dual persona as self'),
#  Document(metadata={'source': 'speech.txt'}, page_content='dual persona as self addressing self as though addressing another person. Solo speech can be used to'),
#  Document(metadata={'source': 'speech.txt'}, page_content="can be used to memorize or to test one's memorization of things, and in prayer or in"),
#  Document(metadata={'source': 'speech.txt'}, page_content='and in prayer or in meditation.\n\nResearchers study many different aspects of speech: speech'),
#  Document(metadata={'source': 'speech.txt'}, page_content='of speech: speech production and speech perception of the sounds used in a language, speech'),
#  Document(metadata={'source': 'speech.txt'}, page_content='a language, speech repetition, speech errors, the ability to map heard spoken words onto the'),
#  Document(metadata={'source': 'speech.txt'}, page_content="words onto the vocalizations needed to recreate them, which plays a key role in children's"),
#  Document(metadata={'source': 'speech.txt'}, page_content="role in children's enlargement of their vocabulary, and what different areas of the human brain,"),
#  Document(metadata={'source': 'speech.txt'}, page_content="of the human brain, such as Broca's area and Wernicke's area, underlie speech. Speech is the subject"),
#  Document(metadata={'source': 'speech.txt'}, page_content='is the subject of study for linguistics, cognitive science, communication studies, psychology,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='studies, psychology, computer science, speech pathology, otolaryngology, and acoustics. \n\nSpeech'),
#  Document(metadata={'source': 'speech.txt'}, page_content='acoustics. \n\nSpeech compares with written language,[1] which may differ in its vocabulary, syntax,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='vocabulary, syntax, and phonetics from the spoken language, a situation called diglossia.\n\nThe'),
#  Document(metadata={'source': 'speech.txt'}, page_content='diglossia.\n\nThe evolutionary origin of speech is subject to debate and speculation. While animals'),
#  Document(metadata={'source': 'speech.txt'}, page_content='While animals also communicate using vocalizations, and trained apes such as Washoe and Kanzi can'),
#  Document(metadata={'source': 'speech.txt'}, page_content="Washoe and Kanzi can use simple sign language, no animals' vocalizations are articulated"),
#  Document(metadata={'source': 'speech.txt'}, page_content='are articulated phonemically and syntactically, and do not constitute speech.')]

# %%
speech = ""
with open("speech.txt") as f:
    speech = f.read()

speech

type([speech])

text_splitter =  CharacterTextSplitter(chunk_size = 100, chunk_overlap = 20)
text = text_splitter.create_documents([speech])


print(text[0])
print(text[2])
# Out:
# Created a chunk of size 403, which is longer than the specified 100
# Created a chunk of size 196, which is longer than the specified 100
# Created a chunk of size 615, which is longer than the specified 100
# Created a chunk of size 589, which is longer than the specified 100
# Created a chunk of size 155, which is longer than the specified 100
# page_content='Speech is the use of the human voice as a medium for language. Spoken language combines vowel and consonant sounds to form units of meaning like words, which belong to a language's lexicon. There are many different intentional speech acts, such as informing, declaring, asking, persuading, directing; acts may vary in various aspects like enunciation, intonation, loudness, and tempo to convey meaning.'
# page_content='While normally used to facilitate communication with others, people may also use speech without the intent to communicate. Speech may nevertheless express emotions or desires; people talk to themselves sometimes in acts that are a development of what some psychologists (e.g., Lev Votsky) have maintained is the use of silent speech in an interior monologue to vivify and organize cognition, sometimes in the momentary adoption of a dual persona as self addressing self as though addressing another person. Solo speech can be used to memorize or to test one's memorization of things, and in prayer or in meditation.'
